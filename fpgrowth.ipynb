# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavbammidi1401/Tests/blob/main/fpgrowth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import threading
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
# warnings.filterwarnings("ignore",category=FutureWarning)
from mlxtend.frequent_patterns import apriori,fpgrowth,association_rules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Groceries_dataset (2).csv")

# %%
df.shape
# Out:
# (38765, 3)

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
df.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
df['Quantity'] = 1
transactions =  df.groupby(['Member_number','itemDescription'])['Quantity'].sum().unstack().reset_index().set_index('Member_number')
def encode(x):
  if x >= 0:
    return 1
  else:
    return 0
basket = transactions.applymap(encode)
basket
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# 1000                            0               0     0              0
# 1001                            0               0     0              0
# 1002                            0               0     0              0
# 1003                            0               0     0              0
# 1004                            0               0     0              0
# ...                           ...             ...   ...            ...
# 4996                            0               0     0              0
# 4997                            0               0     0              0
# 4998                            0               0     0              0
# 4999                            0               0     0              0
# 5000                            0               0     0              0
#
# itemDescription  bathroom cleaner  beef  berries  ...  turkey  vinegar  \
# Member_number                                     ...
# 1000                            0     0        0  ...       0        0
# 1001                            0     1        0  ...       0        0
# 1002                            0     0        0  ...       0        0
# 1003                            0     0        0  ...       0        0
# 1004                            0     0        0  ...       0        0
# ...                           ...   ...      ...  ...     ...      ...
# 4996                            0     0        0  ...       0        0
# 4997                            0     0        0  ...       0        0
# 4998                            0     0        0  ...       0        0
# 4999                            0     0        1  ...       0        0
# 5000                            0     0        0  ...       0        0
#
# itemDescription  waffles  whipped/sour cream  whisky  white bread  white wine  \
# Member_number
# 1000                   0                   0       0            0           0
# 1001                   0                   1       0            1           0
# 1002                   0                   0       0            0           0
# 1003                   0                   0       0            0           0
# 1004                   0                   0       0            0           0
# ...                  ...                 ...     ...          ...         ...
# 4996                   0                   0       0            0           0
# 4997                   0                   0       0            0           1
# 4998                   0                   0       0            0           0
# 4999                   0                   1       0            0           0
# 5000                   0                   0       0            0           0
#
# itemDescription  whole milk  yogurt  zwieback
# Member_number
# 1000                      1       1         0
# 1001                      1       0         0
# 1002                      1       0         0
# 1003                      0       0         0
# 1004                      1       0         0
# ...                     ...     ...       ...
# 4996                      0       0         0
# 4997                      1       0         0
# 4998                      0       0         0
# 4999                      0       1         0
# 5000                      0       0         0
#
# [3898 rows x 167 columns]

# %%
aprioricompleted = threading.Event()
fpcompleted = threading.Event()

# %%
executiontime = [0,0]

# %%
def runapriori():
    stime = time.time()
    global aprioriresults
    aprioriresults = apriori(basket, min_support=0.02, use_colnames=True)
    executiontime[0] = time.time() - stime
    aprioricompleted.set()

# %%
def runfp():
    stime = time.time()
    global fpresults
    fpresults = fpgrowth(basket, min_support=0.02, use_colnames=True)
    executiontime[1] = time.time() - stime
    fpcompleted.set()

# %%
apthread = threading.Thread(target=runapriori)
fpthread = threading.Thread(target=runfp)

# %%
print(executiontime)
# Out:
# [0, 0]

# %%
plt.bar(['Apriori', 'FP-Growth'], executiontime, color=['blue','red'])
plt.xlabel('Algorithms')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Time Comparison: Apriori vs FP-Growth');

# %%
mins = float(input("Enter the minimum support threshold: "))
minc = float(input("Enter the minimum confidence threshold: "))
ap = apriori(basket, min_support=mins, use_colnames=True)
print('The results with Apriori is')
print(association_rules(ap, metric='confidence', min_threshold=minc))
fp = fpgrowth(basket, min_support=mins, use_colnames=True)
print('The results with FP-Growth is')
print(association_rules(fp, metric='confidence', min_threshold=minc))
# Out:
# Enter the minimum support threshold: 0.1
# Enter the minimum confidence threshold: 0.1
# The results with Apriori is
#            antecedents         consequents  antecedent support  \
# 0         (whole milk)     (bottled water)            0.458184
# 1      (bottled water)        (whole milk)            0.213699
# 2   (other vegetables)        (rolls/buns)            0.376603
# 3         (rolls/buns)  (other vegetables)            0.349666
# 4   (other vegetables)              (soda)            0.376603
# 5               (soda)  (other vegetables)            0.313494
# 6   (other vegetables)        (whole milk)            0.376603
# 7         (whole milk)  (other vegetables)            0.458184
# 8   (other vegetables)            (yogurt)            0.376603
# 9             (yogurt)  (other vegetables)            0.282966
# 10              (soda)        (rolls/buns)            0.313494
# 11        (rolls/buns)              (soda)            0.349666
# 12        (rolls/buns)        (whole milk)            0.349666
# 13        (whole milk)        (rolls/buns)            0.458184
# 14        (rolls/buns)            (yogurt)            0.349666
# 15            (yogurt)        (rolls/buns)            0.282966
# 16   (root vegetables)        (whole milk)            0.230631
# 17        (whole milk)   (root vegetables)            0.458184
# 18           (sausage)        (whole milk)            0.206003
# 19        (whole milk)           (sausage)            0.458184
# 20              (soda)        (whole milk)            0.313494
# 21        (whole milk)              (soda)            0.458184
# 22    (tropical fruit)        (whole milk)            0.233710
# 23        (whole milk)    (tropical fruit)            0.458184
# 24            (yogurt)        (whole milk)            0.282966
# 25        (whole milk)            (yogurt)            0.458184
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.213699  0.112365    0.245241  1.147597  0.014452    1.041790
# 1             0.458184  0.112365    0.525810  1.147597  0.014452    1.142615
# 2             0.349666  0.146742    0.389646  1.114335  0.015056    1.065502
# 3             0.376603  0.146742    0.419663  1.114335  0.015056    1.074197
# 4             0.313494  0.124166    0.329700  1.051695  0.006103    1.024178
# 5             0.376603  0.124166    0.396072  1.051695  0.006103    1.032237
# 6             0.458184  0.191380    0.508174  1.109106  0.018827    1.101643
# 7             0.376603  0.191380    0.417693  1.109106  0.018827    1.070564
# 8             0.282966  0.120318    0.319482  1.129050  0.013752    1.053660
# 9             0.376603  0.120318    0.425204  1.129050  0.013752    1.084553
# 10            0.349666  0.119805    0.382160  1.092928  0.010187    1.052593
# 11            0.313494  0.119805    0.342627  1.092928  0.010187    1.044316
# 12            0.458184  0.178553    0.510638  1.114484  0.018342    1.107190
# 13            0.349666  0.178553    0.389698  1.114484  0.018342    1.065592
# 14            0.282966  0.111339    0.318415  1.125279  0.012396    1.052011
# 15            0.349666  0.111339    0.393472  1.125279  0.012396    1.072224
# 16            0.458184  0.113135    0.490545  1.070630  0.007464    1.063522
# 17            0.230631  0.113135    0.246920  1.070630  0.007464    1.021630
# 18            0.458184  0.106978    0.519303  1.133394  0.012591    1.127146
# 19            0.206003  0.106978    0.233483  1.133394  0.012591    1.035850
# 20            0.458184  0.151103    0.481997  1.051973  0.007465    1.045971
# 21            0.313494  0.151103    0.329787  1.051973  0.007465    1.024310
# 22            0.458184  0.116470    0.498353  1.087672  0.009388    1.080076
# 23            0.233710  0.116470    0.254199  1.087672  0.009388    1.027473
# 24            0.458184  0.150590    0.532185  1.161510  0.020940    1.158185
# 25            0.282966  0.150590    0.328667  1.161510  0.020940    1.068076
#
#     zhangs_metric
# 0        0.237376
# 1        0.163569
# 2        0.164589
# 3        0.157772
# 4        0.078849
# 5        0.071601
# 6        0.157802
# 7        0.181562
# 8        0.183350
# 9        0.159406
# 10       0.123855
# 11       0.130743
# 12       0.157955
# 13       0.189591
# 14       0.171191
# 15       0.155267
# 16       0.085746
# 17       0.121758
# 18       0.148230
# 19       0.217222
# 20       0.071966
# 21       0.091184
# 22       0.105189
# 23       0.148768
# 24       0.193926
# 25       0.256640
# The results with FP-Growth is
#            antecedents         consequents  antecedent support  \
# 0               (soda)        (whole milk)            0.313494
# 1         (whole milk)              (soda)            0.458184
# 2               (soda)        (rolls/buns)            0.313494
# 3         (rolls/buns)              (soda)            0.349666
# 4   (other vegetables)              (soda)            0.376603
# 5               (soda)  (other vegetables)            0.313494
# 6             (yogurt)        (whole milk)            0.282966
# 7         (whole milk)            (yogurt)            0.458184
# 8   (other vegetables)            (yogurt)            0.376603
# 9             (yogurt)  (other vegetables)            0.282966
# 10        (rolls/buns)            (yogurt)            0.349666
# 11            (yogurt)        (rolls/buns)            0.282966
# 12           (sausage)        (whole milk)            0.206003
# 13        (whole milk)           (sausage)            0.458184
# 14        (rolls/buns)        (whole milk)            0.349666
# 15        (whole milk)        (rolls/buns)            0.458184
# 16  (other vegetables)        (rolls/buns)            0.376603
# 17        (rolls/buns)  (other vegetables)            0.349666
# 18  (other vegetables)        (whole milk)            0.376603
# 19        (whole milk)  (other vegetables)            0.458184
# 20    (tropical fruit)        (whole milk)            0.233710
# 21        (whole milk)    (tropical fruit)            0.458184
# 22   (root vegetables)        (whole milk)            0.230631
# 23        (whole milk)   (root vegetables)            0.458184
# 24        (whole milk)     (bottled water)            0.458184
# 25     (bottled water)        (whole milk)            0.213699
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.458184  0.151103    0.481997  1.051973  0.007465    1.045971
# 1             0.313494  0.151103    0.329787  1.051973  0.007465    1.024310
# 2             0.349666  0.119805    0.382160  1.092928  0.010187    1.052593
# 3             0.313494  0.119805    0.342627  1.092928  0.010187    1.044316
# 4             0.313494  0.124166    0.329700  1.051695  0.006103    1.024178
# 5             0.376603  0.124166    0.396072  1.051695  0.006103    1.032237
# 6             0.458184  0.150590    0.532185  1.161510  0.020940    1.158185
# 7             0.282966  0.150590    0.328667  1.161510  0.020940    1.068076
# 8             0.282966  0.120318    0.319482  1.129050  0.013752    1.053660
# 9             0.376603  0.120318    0.425204  1.129050  0.013752    1.084553
# 10            0.282966  0.111339    0.318415  1.125279  0.012396    1.052011
# 11            0.349666  0.111339    0.393472  1.125279  0.012396    1.072224
# 12            0.458184  0.106978    0.519303  1.133394  0.012591    1.127146
# 13            0.206003  0.106978    0.233483  1.133394  0.012591    1.035850
# 14            0.458184  0.178553    0.510638  1.114484  0.018342    1.107190
# 15            0.349666  0.178553    0.389698  1.114484  0.018342    1.065592
# 16            0.349666  0.146742    0.389646  1.114335  0.015056    1.065502
# 17            0.376603  0.146742    0.419663  1.114335  0.015056    1.074197
# 18            0.458184  0.191380    0.508174  1.109106  0.018827    1.101643
# 19            0.376603  0.191380    0.417693  1.109106  0.018827    1.070564
# 20            0.458184  0.116470    0.498353  1.087672  0.009388    1.080076
# 21            0.233710  0.116470    0.254199  1.087672  0.009388    1.027473
# 22            0.458184  0.113135    0.490545  1.070630  0.007464    1.063522
# 23            0.230631  0.113135    0.246920  1.070630  0.007464    1.021630
# 24            0.213699  0.112365    0.245241  1.147597  0.014452    1.041790
# 25            0.458184  0.112365    0.525810  1.147597  0.014452    1.142615
#
#     zhangs_metric
# 0        0.071966
# 1        0.091184
# 2        0.123855
# 3        0.130743
# 4        0.078849
# 5        0.071601
# 6        0.193926
# 7        0.256640
# 8        0.183350
# 9        0.159406
# 10       0.171191
# 11       0.155267
# 12       0.148230
# 13       0.217222
# 14       0.157955
# 15       0.189591
# 16       0.164589
# 17       0.157772
# 18       0.157802
# 19       0.181562
# 20       0.105189
# 21       0.148768
# 22       0.085746
# 23       0.121758
# 24       0.237376
# 25       0.163569
